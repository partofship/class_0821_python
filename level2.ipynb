# %% [markdown]
# 안녕하세요.<br><br>
# 수강생 여러분~!
#
# "Challenge : 사칙연산을 이용해 문제 풀기"는 잘 풀어보셨나요?
#
#
# 너~~무 어려웠어요! 하는 분들을 위해 만들어봤습니다!
#
# 문제 도장깨기 !!!!!
#
# 차근차근 풀어나가면 파이썬 정복 가능입니다!
#
# 화이팅 !
#
# Chapter04의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# <br/>
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
#
# <br>
# <br>
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>
# <br>

# %% [markdown]
# -----

# %% [markdown]
# <br>
#
# __[문제1]__
#
# 한 주머니에 사탕이 5개씩 들어있습니다.
#
# 바리바리스타인 나에게는 3개의 주머니가 있습니다!
#
# 근데 길가다가 사탕을 주웠습니다. 그래서 사탕 3개가 주머니에 더 추가되었습니다.
#
# 최종적으로 주머니에 들어있는 사탕의 총 개수는 얼마인가요?
#
# <br>

# %%
pocket_candy_qtt=5
pocket_personal=3
extra_candy=3

print(f"{pocket_candy_qtt*pocket_personal+extra_candy}")    #18
# Out:
# 18

# %% [markdown]
# <br>
#
# __[문제2]__
#
# 10명이 각자 4개의 공을 가지고 있습니다.
#
# 운이 좋은 3명이 2개의 공을 더 받았습니다.
#
# 10명이 가진 모든 공의 총 개수를 구하세요.

# %%
people_qtt=10
basic_ball_qtt=4
people_special=3
special_ball_qtt=basic_ball_qtt+2
people_qtt -= people_special
print(f"{people_qtt*basic_ball_qtt+special_ball_qtt*people_special}")    #46
# Out:
# 46

# %% [markdown]
# <br>
#
# __[문제3]__
#
# 5명의 학생이 3시간씩 공부했습니다.
#
# 이상한 강박관념이 있는 나는 모든 시간을 분으로 계산하고 싶습니다.
#
# 대신 계산해주세요 !

# %%
student_qtt=5
study_hour=3
minute_p_hour=60
total_minute=student_qtt*study_hour*minute_p_hour
print(total_minute)    #900
# Out:
# 900

# %% [markdown]
# <br>
#
# __[문제4]__
#
# 차가 9리터의 연료를 가지고 있습니다.
#
# 연료가 3일 동안 계속 줄어들며, 하루에 2리터씩 소비됩니다.
#
# 3일 뒤 차에 남은 연료는 몇 리터인가요?

# %%
fuel_tank=9
day=3
fuel_usage=2
fuel_remain=fuel_tank-day*fuel_usage
print(fuel_remain)    #3
# Out:
# 3

# %% [markdown]
# __[문제5]__
#
# 어떤 정사각형의 넓이가 144cm²입니다.
#
# 정사각형의 한 변의 길이를 구하세요.

# %%
rect_area=144
rect_side=rect_area**0.5
print(f"rectangle side: {rect_side} cm^2")
# Out:
# rectangle side: 12.0 cm^2

# %% [markdown]
# <br>
#
# __[문제6]__
#
# 오즈 코딩 스쿨 백엔드 과정에 참여한 수강생 중 5명의 수강생이 자율적으로 스터디 그룹을 결성했습니다.
#
# 스터디 그룹 내에는 한 주간 배운 내용으로 매주 쪽지 시험을 보는 룰이 있습니다.
#
# 이 쪽지 시험의 평균이 70점이 넘으면 주말 스터디는 없습니다.
#
# 이들의 평균 점수를 대신 계산해주세요.
#
# <br>
# A: 65, B: 75, C: 50, D: 80, E: 60
#
# <br>

# %%
score_student=[65, 75, 50, 80, 60]
avg_score=(sum(score_student))/5
print(avg_score)    #66.0
# Out:
# 66.0
